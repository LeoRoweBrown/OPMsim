# %%
import numpy as np
from single_dipole import simulate_single_dipole

print("running simulations")
## angles
phi = np.linspace(0, np.pi, 12)
theta = np.linspace(0, np.pi, 12)

phi = np.arange(0, np.pi, np.pi/6)
theta = np.arange(0,  np.pi, np.pi/6)

phi = np.arange(0, 2*np.pi, np.pi/4)
theta = np.arange(0,  np.pi/2, np.pi/6)
theta = np.arange(0,  np.pi/2+0.1, np.pi/6)

save_dir = 'C:/Users/Leo/Documents/fogim/single_dipole_sims_transformation_alpha_xyfix_attempt'
save_dir = 'Z:/User data/Leo Rowe-Brown/OPMsim_output/single_dipole_xyfix_curved'
# save_dir = None

for p in phi:
    for t in theta:
        print((p, t))
        simulate_single_dipole(p, t, 0.9, save_dir=save_dir, plot_pupil=True, curved_coords=True)
# Out:
# running simulations
# (0.0, 0.0)
# 100
# 50
# 5000
# Saving in Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_xyfix_curved
# No directory, Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_xyfix_curved\theta_dipole_0.0, making it
# (0.0, 0.5235987755982988)
# 100
# 50
# 5000
# Saving in Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_xyfix_curved
# No directory, Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_xyfix_curved\theta_dipole_30.0, making it
# (0.0, 1.0471975511965976)
# 100
# 50
# 5000
# Saving in Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_xyfix_curved
# No directory, Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_xyfix_curved\theta_dipole_60.0, making it
# (0.0, 1.5707963267948966)
# 100
# 50
# 5000
# Saving in Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_xyfix_curved
# No directory, Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_xyfix_curved\theta_dipole_90.0, making it
# (0.7853981633974483, 0.0)
# ...

# %%
import numpy as np
from single_dipole import simulate_single_dipole
from single_dipole import simulate_single_dipole_cartesian

print("running simulations")
## angles
phi = np.linspace(0, np.pi, 12)
theta = np.linspace(0, np.pi, 12)

phi = np.arange(0, np.pi, np.pi/6)
theta = np.arange(0,  np.pi, np.pi/6)

phi = np.arange(0, 2*np.pi, np.pi/4)
theta = np.arange(0,  np.pi/2, np.pi/6)
theta = np.arange(0,  np.pi/2+0.1, np.pi/6)

save_dir = 'C:/Users/Leo/Documents/fogim/single_dipole_sims_transformation_flat'
save_dir = 'Z:/User data/Leo Rowe-Brown/OPMsim_output/single_dipole_flat'
# save_dir = None

for p in phi:
    for t in theta:
        print((p, t))
        # NA of 1 with a flat pupil goes to inifinity in diameter!!
        # simulate_single_dipole_cartesian(p, t, 0.8, save_dir=save_dir, plot_pupil=True)
        simulate_single_dipole(p, t, 0.9, save_dir=save_dir, plot_pupil=True, flat_pupil=True, curved_coords=False)
# Out:
# running simulations
# (0.0, 0.0)
# 100
# 50
# 5000
# Saving in Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_flat
# No directory, Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_flat\theta_dipole_0.0, making it
# (0.0, 0.5235987755982988)
# 100
# 50
# 5000
# Saving in Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_flat
# No directory, Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_flat\theta_dipole_30.0, making it
# (0.0, 1.0471975511965976)
# 100
# 50
# 5000
# Saving in Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_flat
# No directory, Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_flat\theta_dipole_60.0, making it
# (0.0, 1.5707963267948966)
# 100
# 50
# 5000
# Saving in Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_flat
# No directory, Z:\User data\Leo Rowe-Brown\OPMsim_output\single_dipole_flat\theta_dipole_90.0, making it
# (0.7853981633974483, 0.0)
# 100
# 50
# 5000
# ...

# %%
import os
save_dir = 'C:/Users/Leo/Documents/fogim/single_dipole_sims'
os.path.isdir(save_dir)
if not os.path.isdir(save_dir):
    print("No directory, %s making it" % save_dir)
    os.mkdir(save_dir)

# %%
import numpy as np
for x in range(20):
    val = -1 + 2*np.random.randint(2)
    print(val)
